# %% [markdown]
# <a href="https://colab.research.google.com/github/Nishantarya80/Better_Doctor/blob/master/Yelpfusion.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pure yelp fusion

# %%
import numpy as np
import pandas as pd
import json
import requests

# %%
def get_businesses(location, term, api_key):
    headers = {'Authorization': 'Bearer %s' % api_key}
    url = 'https://api.yelp.com/v3/businesses/search'

    data = []
    for offset in range(0, 1000, 50):
        params = {
            'limit': 50, 
            'location': location.replace(' ', '+'),
            'term': term.replace(' ', '+'),
            'offset': offset
        }

        response = requests.get(url, headers=headers, params=params)
        if response.status_code == 200:
            data += response.json()['businesses']
        elif response.status_code == 400:
            print('400 Bad Request')
            break

    return data

# %%
api_key = 'mrXRu-DLXokt_46ZcJOy_iUc7Yt_bujSo72VF1TbWhjRVyT34sZwLwty_p1LHYTMuudKEZgncTIkHiv2ub7kZKVF5e928GPC8aOpP5yau9COv8Cz28yhsVe7PpeIXHYx'

all_data=get_businesses('New York City', 'Doctor', api_key)

# %%
uid=[]
disp_address=[]
name=[]
review_count=[]
url=[]
overall_rating=[]
for businesses in all_data:
  name.append(businesses['name'])
  uid.append(businesses['id'])
  review_count.append(businesses['review_count'])
  url.append(businesses['url'])
  disp_address.append(businesses['location']['display_address'])
  overall_rating.append(businesses['rating'])
    
dict = {'Name': name, 'UID': uid, 'Address': disp_address, 'Reviews_count':review_count,'URL':url,'Overall_Rating':overall_rating}      
data_frame = pd.DataFrame(dict)

# %%
data_frame['URL']=data_frame['URL'].str.split('?').apply(lambda x: x[0])

# %%
def doc_function(get_id):
  rating=[]
  review=[]
  ids=[]
  Date=[]
  New_Url="https://api.yelp.com/v3/businesses/Awrxm7Xdm04onsEWpFj9BQ/reviews"
  data=requests.get(New_Url, params=params, headers=headers)
  per_person_data=json.loads(data.text)
  for data in per_person_data['reviews']:
    rating.append(data['rating'])
    review.append(data['text'])
    ids.append(get_id)
    Date.append(data['time_created'])
  dict = {'Review': review, 'UID': ids, 'Rating': rating, 'Date':Date }          
  return dict

# %%
final_df = pd.DataFrame(columns=['Review','UID','Rating','Date'])#empty data frame
for set_id in data_frame['UID']:
  final_df=final_df.append(pd.DataFrame(doc_function(set_id)),ignore_index=True)

# %%
final_df
# Out:
#                      Date Rating  \
# 0     2017-12-19 15:27:08      5
# 1     2018-04-12 17:12:05      5
# 2     2015-04-21 12:15:38      1
# 3     2017-12-19 15:27:08      5
# 4     2018-04-12 17:12:05      5
# 5     2015-04-21 12:15:38      1
# 6     2017-12-19 15:27:08      5
# 7     2018-04-12 17:12:05      5
# 8     2015-04-21 12:15:38      1
# 9     2017-12-19 15:27:08      5
# 10    2018-04-12 17:12:05      5
# 11    2015-04-21 12:15:38      1
# 12    2017-12-19 15:27:08      5
# 13    2018-04-12 17:12:05      5
# 14    2015-04-21 12:15:38      1
# 15    2017-12-19 15:27:08      5
# 16    2018-04-12 17:12:05      5
# 17    2015-04-21 12:15:38      1
# 18    2017-12-19 15:27:08      5
# 19    2018-04-12 17:12:05      5
# 20    2015-04-21 12:15:38      1
# 21    2017-12-19 15:27:08      5
# 22    2018-04-12 17:12:05      5
# 23    2015-04-21 12:15:38      1
# 24    2017-12-19 15:27:08      5
# 25    2018-04-12 17:12:05      5
# 26    2015-04-21 12:15:38      1
# 27    2017-12-19 15:27:08      5
# 28    2018-04-12 17:12:05      5
# 29    2015-04-21 12:15:38      1
# ...                   ...    ...
# 2970  2017-12-19 15:27:08      5
# 2971  2018-04-12 17:12:05      5
# 2972  2015-04-21 12:15:38      1
# 2973  2017-12-19 15:27:08      5
# 2974  2018-04-12 17:12:05      5
# 2975  2015-04-21 12:15:38      1
# 2995  Dr Lee has become my PCP. He is very knowledge...
# 2996  I can't even call their office because they're...
# 2997  Dr. Lee is a very thoughtful doctor who listen...
# 2998  Dr Lee has become my PCP. He is very knowledge...
# 2999  I can't even call their office because they're...
#
#                          UID
# 0     GFfbbpxBB041X2RR9VYEew
# 1     GFfbbpxBB041X2RR9VYEew
# 2     GFfbbpxBB041X2RR9VYEew
# 3     _akjzY2DgJcy1UtXJh50KQ
# 4     _akjzY2DgJcy1UtXJh50KQ
# 5     _akjzY2DgJcy1UtXJh50KQ
# 6     sUwC1VYi2XJIXIFACiO7bQ
# 7     sUwC1VYi2XJIXIFACiO7bQ
# 8     sUwC1VYi2XJIXIFACiO7bQ
# 9     yvlNsAIoWVRR2e9J46Y92g
# 10    yvlNsAIoWVRR2e9J46Y92g
# 11    yvlNsAIoWVRR2e9J46Y92g
# 12    2sfleXK42MT1mDYCuYEP4w
# 13    2sfleXK42MT1mDYCuYEP4w
# 14    2sfleXK42MT1mDYCuYEP4w
# 15    -Ghfa2Z9MIpz-1x968-ngA
# 16    -Ghfa2Z9MIpz-1x968-ngA
# 17    -Ghfa2Z9MIpz-1x968-ngA
# 18    qirjSRPKeA8lCtStyaoSng
# 19    qirjSRPKeA8lCtStyaoSng
# 20    qirjSRPKeA8lCtStyaoSng
# 21    J1JVs7sQV3-5AJI3rLWaVQ
# 22    J1JVs7sQV3-5AJI3rLWaVQ
# 23    J1JVs7sQV3-5AJI3rLWaVQ
# 24    xdwQTt8r-Em0Ue02jTFHYg
# 25    xdwQTt8r-Em0Ue02jTFHYg
# 26    xdwQTt8r-Em0Ue02jTFHYg
# 27    aiKDY_1FByDqewNVvVEMUA
# 28    aiKDY_1FByDqewNVvVEMUA
# 29    aiKDY_1FByDqewNVvVEMUA
# ...                      ...
# 2970  EpRqLp5upBJRrrWcpPoGyQ
# 2971  EpRqLp5upBJRrrWcpPoGyQ
# 2972  EpRqLp5upBJRrrWcpPoGyQ
# 2973  pfi_hMgyMCWyBBGEUpj6Xw
# 2974  pfi_hMgyMCWyBBGEUpj6Xw
# 2975  pfi_hMgyMCWyBBGEUpj6Xw
# 2976  fFSj9E0zhJGKRSmHgpQolQ
# 2977  fFSj9E0zhJGKRSmHgpQolQ
# 2978  fFSj9E0zhJGKRSmHgpQolQ
# 2979  PcYQECT9vuz60f4CVo5TpQ
# 2980  PcYQECT9vuz60f4CVo5TpQ
# 2981  PcYQECT9vuz60f4CVo5TpQ
# 2982  ddA6qhdyVyx-ylhajXbDeA
# 2983  ddA6qhdyVyx-ylhajXbDeA
# 2984  ddA6qhdyVyx-ylhajXbDeA
# 2985  LntDp5sOxOHI7lHBilabqQ
# 2986  LntDp5sOxOHI7lHBilabqQ
# 2987  LntDp5sOxOHI7lHBilabqQ
# 2988  rvBqkE2aZeHU0lzfVeYPtQ
# 2989  rvBqkE2aZeHU0lzfVeYPtQ
# 2990  rvBqkE2aZeHU0lzfVeYPtQ
# 2991  DhSHbMcsd588eWDuhoGwbw
# 2992  DhSHbMcsd588eWDuhoGwbw
# 2993  DhSHbMcsd588eWDuhoGwbw
# 2994  tJJHFbq6O0Jo-5weMs62sw
# 2995  tJJHFbq6O0Jo-5weMs62sw
# 2996  tJJHFbq6O0Jo-5weMs62sw
# 2997  RtKu0Be5a0_skaguUME6OQ
# 2998  RtKu0Be5a0_skaguUME6OQ
# 2999  RtKu0Be5a0_skaguUME6OQ
#
# [3000 rows x 4 columns]

# %%
final_df.to_csv('New_York_R.csv')
data_frame.to_csv('New_York_DR.csv')
